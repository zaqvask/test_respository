# %% [markdown]
# <a href="https://colab.research.google.com/github/zaqvask/test_respository/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("ljad")
# Out:
# ljad

# %%
import math
angel =90
math.sin(90*math.pi/180)
# Out:
# 1.0

# %%
from PIL import Image

# %%
im = Image.open("/content/drive/MyDrive/Colab Notebooks/yen.jpeg")

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=808x842 at 0x7F606F82AC10>

# %%
Image.open("/content/drive/MyDrive/Colab Notebooks/yen.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=808x842 at 0x7F604E2FA550>
